# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('//content/EdStatsCountry.csv')

# %%
df.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
# Inspecting the columns for relevant features and missing values
data.info()

useful_columns = ['Latest population census', 'Latest trade data', 'Income Group', 'Region']
selected_data = data[useful_columns]

# Checking for missing values in the selected columns
selected_data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-da5255c250a7> in <cell line: 2>()
#       1 # Inspecting the columns for relevant features and missing values
# ----> 2 data.info()
#       3
#       4 # Selecting numeric and categorical columns that can be useful for ML
#       5 # Numeric columns with potential information: "Latest population census", "Latest trade data"
#
# NameError: name 'data' is not defined
